# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import ss2tf, tf2sos, dlti, dimpulse

from pyFDN.generate.random_orthogonal import random_orthogonal
from pyFDN.translate.dss2impz import dss2impz
from pyFDN.translate.dss2ss import dss2ss

def isAlmostZero(x, tol=1e-12):
    return np.all(np.abs(x) < tol)


# ---------------- Example run ---------------- #
np.random.seed(1)

# Lossless feedback matrix
N = 3
m = np.array([13, 19, 23])
g = 0.9
A = random_orthogonal(N) @ np.diag(g ** m)
b = np.random.randn(N, 1)
c = np.random.randn(1, N)
d = np.random.randn(1, 1)

# State-space transition matrix
AA, bb, cc, dd = dss2ss(m, A, b, c, d)

# Compare impulse response
impulseResponseLength = 100

# Transfer function from state-space
num, den = ss2tf(AA, bb, cc, dd)
system = dlti(num, den)
t, irStateSpace_TF = dimpulse(system, n=impulseResponseLength)
irStateSpace_TF = np.squeeze(irStateSpace_TF)

# SOS representation
sos = tf2sos(num, den)
# Compute impulse response for SOS by converting to TF first
irStateSpace_SOS = np.zeros_like(irStateSpace_TF)
for section in sos:
    b_s, a_s = section[:3], section[3:]
    system_s = dlti(b_s, a_s)
    _, ir_s = dimpulse(system_s, n=impulseResponseLength)
    irStateSpace_SOS += np.squeeze(ir_s)
    
# Delay state-space impulse response
irDelayStateSpace = dss2impz(impulseResponseLength, m, A, b, c, d)

# Plot
plt.figure()
plt.plot(irStateSpace_TF, label='State Space TF')
plt.plot(irStateSpace_SOS + 2, label='State Space SOS')
plt.plot(irDelayStateSpace + 4, label='Delay State Space')
plt.xlabel("Time [samples]")
plt.ylabel("Amplitude [linear]")
plt.grid(True)
plt.legend()
plt.show()

# ---------------- Tests ---------------- #
# All eigenvalues lie on the circle with radius g
e = np.linalg.eigvals(AA)
print(f"The pole magnitudes are between {np.min(np.abs(e))} and {np.max(np.abs(e))}")
assert isAlmostZero(np.abs(e) - g)

# Transfer function matches delay state-space
assert isAlmostZero(irStateSpace_TF - irDelayStateSpace, tol=0.001)

# SOS matches delay state-space
assert isAlmostZero(irStateSpace_SOS - irDelayStateSpace, tol=1e-12)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 48
#      45     irStateSpace_SOS += np.squeeze(ir_s)
#      47 # Delay state-space impulse response
# ---> 48 irDelayStateSpace = dss2impz(impulseResponseLength, m, A, b, c, d)
#      50 # Plot
#      51 plt.figure()
#
# File ~/Documents/ss25/pyFDN/src/pyFDN/translate/dss2impz.py:42, in dss2impz(ir_len, delays, A, B, C, D, input_type, extra_matrix, absorption_filters)
#      39 input_signal[0, :] = 1
#      41 # Process FDN
# ---> 42 impulse_response = processFDN(
#      43     input_signal,
#      44     delays,
#      45     A,
#      46     B,
#      47     C,
#      48     D,
#      49     input_type=input_type,
#      50     extra_matrix=extra_matrix,
#      51     absorption_filters=absorption_filters
#      52 )
#      54 return impulse_response
#
# File ~/Documents/ss25/pyFDN/src/pyFDN/auxiliary/processFDN.py:69, in processFDN(input_signal, delays, A, B, C, D, input_type, extra_matrix, absorption_filters)
#      67     in_block = np.zeros_like(input_signal)
#      68     in_block[:, it_in] = input_signal[:, it_in]
# ---> 69     output[:, :, it_in] = computeFDNloop(in_block, delays, feedback_matrix, input_gains, output_gains, extra_matrix, absorption_filters)
#      70 # Add direct path
#      71 D = np.array(D).reshape(output.shape[1], output.shape[2])  # [out, in]
#
# File ~/Documents/ss25/pyFDN/src/pyFDN/auxiliary/processFDN.py:113, in computeFDNloop(input_signal, delays, feedback_matrix, input_gains, output_gains, extra_matrix, absorption_filters)
#     110     feedback = extra_matrix.filter(feedback)
#     112 # Input + feedback
# --> 113 delay_line_input = input_gains.filter(block) + feedback
#     114 delay_filters.set_values(delay_line_input)
#     116 # Compute output
#
# File ~/Documents/ss25/pyFDN/src/pyFDN/dsp/dfiltmatrix.py:56, in DFiltMatrix.filter(self, x)
#      54         out = x * self.filters
#      55     else:
# ---> 56         out = x @ self.filters.T
#      57 else:
#      58     # Object filters (ZFilter)
#      59     if self.is_diagonal:
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 1 is different from 3)
